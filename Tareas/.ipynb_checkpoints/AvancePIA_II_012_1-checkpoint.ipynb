# %% [markdown]
# <h2 align="center"> Video Game Sales / Avance II </h2>
#
# <h2 align="center"> Equipo 1. Grupo 012, Martes y Jueves 6:30 pm a 8:00 pm. </h2>
#
# ## INTEGRANTES:
# ● Edgar Bladimir López Alonzo 1753141.
#
# ● Cristian Antonio Jaramillo Arriaga 1680776.
#
# ## PROFESORA
#
# Mayra Cristina Berrones Reyes.

# %% [markdown]
# ## Título de la base de datos
# Video Game Sales
#
# https://www.kaggle.com/gregorut/videogamesales
#
# ## Descripción de los datos
#
# Este conjunto de datos contiene una lista de videojuegos con ventas superiores a 100.000 copias.
#
# Las columnas incluyen
#
# ●	Rango (Int) - Clasificación de las ventas totales
#
# ●	Nombre (String) - El nombre de los juegos
#
# ●	Plataforma (String) - Plataforma del lanzamiento de juegos (es decir, PC, PS4, etc.)
#
# ●	Año (Int) - Año del lanzamiento del juego
#
# ●	Género (String) - Género del juego
#
# ●	Editor (String) - Editor del juego
#
# ●	NA_Sales (Double) - Ventas en América del Norte (en millones)
#
# ●	EU_Sales (Double) - Ventas en Europa (en millones)
#
# ●	JP_Sales (Double) - Ventas en Japón (en millones)
#
# ●	Other_Sales (Double) - Ventas en el resto del mundo (en millones)
#
# ●	Global_Sales (Double) - Total de ventas en todo el mundo.
#
# ## Justificación de los datos
#
# En los últimos años los videojuegos se convirtieron en una industria multimillonaria por la tendencia que tiene con los jóvenes del mundo. Debido al desarrollo de la computación, capacidad de procesamiento e imágenes más reales hay una gran batalla de competición entre las empresas desarrolladoras.
#
# ## Planteamiento del problema
#
# La fabricación en los videojuegos se ha convertido en un gran problema para las compañías. Hay demasiada demanda en diferentes géneros para  distintos públicos, pero esto no quiere decir que todos tengan la acepción deseada desde el inicio del desarrollo del videojuego. Con esto buscamos orientar la toma de decisión en las compañías para el desarrollo de un videojuego que busquen en qué plataforma apostar y que géneros serían los más factibles para orientar sus desarrollos.
#
# ## Objetivo final
#
# Con base a la información dada por la base de datos.
#
# Objetivo Principal:
#
# ●	Elaborar una herramienta que nos permita saber qué tipo de género del videojuego para ser desarrollado.
#
# Objetivo secundario:
#
# ●	En qué plataforma será factible distribuirlo
#
# ## Planeación de la herramienta a utilizar
#
# Utilizando la técnica de regresión lineal se generará una gráfica con cada combinación a nivel consola, género y compañía contra el número de ventas de cada una.
#
# ●	Género con ventas
#
# ●	Consola con ventas
#
# ●	Compañía con ventas
#
# Se planea usar esta técnica ya que tenemos varios puntos que consideramos importantes como lo son el género, consola y compañía, y cada uno está relacionado con la columna central de interés (número de ventas), con lo cual resulta más sencillo con esta técnica generar una gráfica utilizando como X y Y cada uno de estos puntos junto con el número de ventas con la finalidad de comparar cada una de estas gráficas y usarlas como referencia para los objetivos planteados.
#
#
#
# ## Desarrollo de las herramientas
#
# Tipos de dato en las columnas:

# %%
import pandas as pandas
import seaborn as sns
import matplotlib.pyplot as plt

vgSalesOriginal = pandas.read_csv("vgsales.csv",encoding='utf8')

# %%
vgSalesOriginal.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# A continuación se mostraran los 5 primeros registros de la base de datos, para tener una mejor visualización de los datos.

# %%
vgSalesOriginal.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# Algunos de nuestros datos mostraban información nula. Se decidió eliminarlos sin llegar afectar nuestro resultado.

# %%
vgSalesOriginal = vgSalesOriginal.dropna()
vgSalesOriginal.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# Para fines prácticos, se cambiaron los nombres de algunas columnas "clave" que serán las principales para nuestro análisis de datos.

# %%
vgSalesOriginal = vgSalesOriginal.rename(columns = {'Name':'NombreJuego'})
vgSalesOriginal = vgSalesOriginal.rename(columns = {'Platform':'Consola'})
vgSalesOriginal = vgSalesOriginal.rename(columns = {'Year':'AnnoPublicacion'})
vgSalesOriginal = vgSalesOriginal.rename(columns = {'Genre':'Genero'})
vgSalesOriginal
# Out:
#         Rank                                       NombreJuego Consola  \
# 0          1                                        Wii Sports     Wii
# 1          2                                 Super Mario Bros.     NES
# 2          3                                    Mario Kart Wii     Wii
# 3          4                                 Wii Sports Resort     Wii
# 4          5                          Pokemon Red/Pokemon Blue      GB
# ...      ...                                               ...     ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5     GBA
# 16594  16597                     Men in Black II: Alien Escape      GC
# 16595  16598  SCORE International Baja 1000: The Official Game     PS2
# 16596  16599                                        Know How 2      DS
# 16597  16600                                  Spirits & Spells     GBA
#
#        AnnoPublicacion        Genero   Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# Para tener una mejor manipulación de los datos, se buscó el tipo de género de videojuego que contienen los datos. Y al mismo tiempo se agruparon los registros por tipo de género encontrado.

# %%
list(vgSalesOriginal.Genero.unique())
# Out:
# ['Sports',
#  'Platform',
#  'Racing',
#  'Role-Playing',
#  'Puzzle',
#  'Misc',
#  'Shooter',
#  'Simulation',
#  'Action',
#  'Fighting',
#  'Adventure',
#  'Strategy']

# %%
vgSalesGeneroPlataforma = vgSalesOriginal[vgSalesOriginal['Genero'] == 'Platform']
vgSalesGeneroPlataforma
# Out:
#         Rank                                       NombreJuego Consola  \
# 1          2                                 Super Mario Bros.     NES
# 6          7                             New Super Mario Bros.      DS
# 8          9                         New Super Mario Bros. Wii     Wii
# 18        19                                 Super Mario World    SNES
# 21        22                                  Super Mario Land      GB
# ...      ...                                               ...     ...
# 16498  16501  The Land Before Time: Into the Mysterious Beyond     GBA
# 16562  16565                                      Mighty No. 9    XOne
# 16565  16568                                         Teslagrad     PSV
# 16593  16596                Woody Woodpecker in Crazy Castle 5     GBA
# 16597  16600                                  Spirits & Spells     GBA
#
#        AnnoPublicacion    Genero     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# De la misma forma se agruparon los registros por las principales consolas con mayor venta, las cuales son, Playstation 2, Playstation 3, Nintendo DS, Xbox 360 y Wii

# %%
vgSalesConsolaSNES = vgSalesOriginal[vgSalesOriginal['Consola'] == 'PS2']
vgSalesConsolaSNES = vgSalesOriginal[vgSalesOriginal['Consola'] == 'PS3']
vgSalesConsolaSNES = vgSalesOriginal[vgSalesOriginal['Consola'] == 'DS']
vgSalesConsolaSNES = vgSalesOriginal[vgSalesOriginal['Consola'] == 'X360']
vgSalesConsolaSNES = vgSalesOriginal[vgSalesOriginal['Consola'] == 'Wii']
vgSalesConsolaSNES
# Out:
#         Rank                                        NombreJuego Consola  \
# 0          1                                         Wii Sports     Wii
# 2          3                                     Mario Kart Wii     Wii
# 3          4                                  Wii Sports Resort     Wii
# 7          8                                           Wii Play     Wii
# 8          9                          New Super Mario Bros. Wii     Wii
# ...      ...                                                ...     ...
# 16517  16520                       Teenage Mutant Ninja Turtles     Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!     Wii
# 16573  16576                                Mini Desktop Racing     Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...     Wii
# 16581  16584                                          Fit & Fun     Wii
#
#        AnnoPublicacion    Genero                     Publisher  NA_Sales  \
# ...

# %% [markdown]
# ## Estadistica Basica

# %% [markdown]
# Se establecieron las columnas "fecha" como números enteros

# %%
import pandas as pandas
import seaborn as sns
import matplotlib.pyplot as plt

vgSalesOriginal = pandas.read_csv("vgsales.csv",encoding='utf8')

vgSalesOriginal.Year.astype("Int32")
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16593    2002
# 16594    2003
# 16595    2008
# 16596    2010
# 16597    2003
# Name: Year, Length: 16598, dtype: Int32

# %% [markdown]
# Se eliminan los datos no decimales, se agrupa por género y se saca la suma total de ventas según los géneros.

# %%
vgSalesGeneroSumatoriaVentas = vgSalesOriginal.drop(['Rank', 'Name', 'Year', 'Platform', 'Publisher'],axis = 1 )
vgSalesGeneroSumatoriaVentas = vgSalesGeneroSumatoriaVentas.groupby(['Genre'], as_index=False).sum()
vgSalesGeneroSumatoriaVentas
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         Action    877.83    525.00    159.95       187.38       1751.18
# 1      Adventure    105.80     64.13     52.07        16.81        239.04
# 2       Fighting    223.59    101.32     87.35        36.68        448.91
# 3           Misc    410.24    215.98    107.76        75.32        809.96
# 4       Platform    447.05    201.63    130.77        51.59        831.37
# 5         Puzzle    123.78     50.78     57.31        12.55        244.95
# 6         Racing    359.42    238.39     56.69        77.27        732.04
# 7   Role-Playing    327.28    188.06    352.31        59.61        927.37
# 8        Shooter    582.60    313.27     38.28       102.69       1037.37
# 9     Simulation    183.31    113.38     63.70        31.52        392.20
# 10        Sports    683.35    376.85    135.37       134.97       1330.93
# 11      Strategy     68.70     45.34     49.46        11.36        175.12

# %% [markdown]
# Se eliminan los datos no decimales, se agrupa por plataforma y se saca un promedio de ventas.

# %%
vgSalesPlataformaSumatoriaVentas = vgSalesOriginal.drop(['Rank', 'Name', 'Year', 'Genre', 'Publisher'],axis = 1 )
vgSalesPlataformaSumatoriaVentas = vgSalesPlataformaSumatoriaVentas.groupby(['Platform'], as_index=False).sum()
vgSalesPlataformaSumatoriaVentas
# Out:
#    Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      2600     90.60      5.47      0.00         0.91         97.08
# 1       3DO      0.00      0.00      0.10         0.00          0.10
# 2       3DS     78.87     58.52     97.35        12.63        247.46
# 3        DC      5.43      1.69      8.56         0.27         15.97
# 4        DS    390.71    194.65    175.57        60.53        822.49
# 5        GB    114.32     47.82     85.12         8.20        255.45
# 6       GBA    187.54     75.25     47.33         7.73        318.50
# 7        GC    133.46     38.71     21.58         5.18        199.36
# 8       GEN     19.27      5.52      2.67         0.89         28.36
# 9        GG      0.00      0.00      0.04         0.00          0.04
# 10      N64    139.02     41.06     34.22         4.38        218.88
# 11      NES    125.94     21.15     98.65         5.31        251.07
# 12       NG      0.00      0.00      1.44         0.00          1.44
# ...

# %% [markdown]
# Se eliminan los datos no decimales, se agrupa por desarrollador/distribuidor y se sacan los valores máximos de ventas que ha ganado por un juego.

# %%
vgSalesPublisherVentasMaximas = vgSalesOriginal.drop(['Rank', 'Name', 'Year', 'Platform', 'Genre'],axis = 1 )
vgSalesPublisherVentasMaximas = vgSalesPublisherVentasMaximas.groupby(['Publisher'], as_index=False).max()
vgSalesPublisherVentasMaximas
# Out:
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 10TACLE Studios      0.06      0.03      0.00         0.00
# 1                      1C Company      0.01      0.03      0.00         0.01
# 2    20th Century Fox Video Games      0.74      0.04      0.00         0.01
# 3                          2D Boy      0.00      0.03      0.00         0.01
# 4                             3DO      1.10      0.32      0.00         0.06
# ..                            ...       ...       ...       ...          ...
# 573                   id Software      0.02      0.00      0.00         0.00
# 574               imageepoch Inc.      0.00      0.00      0.03         0.00
# 575          inXile Entertainment      0.02      0.06      0.00         0.01
# 576                     mixi, Inc      0.00      0.00      0.86         0.00
# 577                  responDESIGN      0.07      0.02      0.00         0.01
#
#      Global_Sales
# 0            0.06
# ...

# %% [markdown]
# Se eliminan los datos no decimales, se agrupa por fecha y se sacan la suma total de ventas que hubo en ese año.

# %%
vgSalesYearSumatoriaVentas = vgSalesOriginal.drop(['Rank', 'Name', 'Genre', 'Platform', 'Publisher'],axis = 1 )
vgSalesYearSumatoriaVentas = vgSalesYearSumatoriaVentas.groupby(['Year'], as_index=False).sum()
vgSalesYearSumatoriaVentas
# Out:
#       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0   1980.0     10.59      0.67      0.00         0.12         11.38
# 1   1981.0     33.40      1.96      0.00         0.32         35.77
# 2   1982.0     26.92      1.65      0.00         0.31         28.86
# 3   1983.0      7.76      0.80      8.10         0.14         16.79
# 4   1984.0     33.28      2.10     14.27         0.70         50.36
# 5   1985.0     33.73      4.74     14.56         0.92         53.94
# 6   1986.0     12.50      2.84     19.81         1.93         37.07
# 7   1987.0      8.46      1.41     11.63         0.20         21.74
# 8   1988.0     23.87      6.59     15.76         0.99         47.22
# 9   1989.0     45.15      8.44     18.36         1.50         73.45
# 10  1990.0     25.46      7.63     14.88         1.40         49.39
# 11  1991.0     12.76      3.95     14.78         0.74         32.23
# 12  1992.0     33.87     11.71     28.91         1.65         76.16
# ...

# %% [markdown]
# ## Graficas
#
# La industria tuvo un gran crecimiento entrando en la época de los 2000's, para tener una idea del rango de crecimiento de la industria se hizo una gráfica comparando las ventas durante los años registrados en la base de datos.

# %%
vgSalesYearSumatoriaVentas.plot(x='Year', figsize=(17,10))
plt.xlabel('Año', fontsize=18)
plt.ylabel('Ventas', fontsize=18)
plt.title('Ventas en diferentes zonas', fontweight='bold', fontsize=22)
# Out:
# Text(0.5, 1.0, 'Ventas en diferentes zonas')

# %% [markdown]
# Los años siguientes a partir del 2015 se muestra un declive en la gráfica, esto es por la falta de información actualizada de la base de datos y también por las ventas disminuidas con las consolas de los años 2005 - 2010 fueron desapareciendo a causa de nuevas consolas. Se puede apreciar fácilmente que tuvo un gran crecimiento entre los años 2005 - 2010, esto se debe al lanzamiento de diferentes consolas como por ejemplo la Playstation 3 y la Xbox360. También se puede mencionar que durante ese periodo el funcionamiento de antiguas consolas como la Playstation 2 y la Xbox (primera generación), aun se mostraba activas en el mercado.
#
# Para demostrar lo último mencionado se hizo la siguiente grafica mostrando diferentes consolas de distintas épocas.

# %%
sns.lmplot(x='Global_Sales', y='Year', hue='Platform', figsize=(17,10), 
           data=vgSalesOriginal.loc[vgSalesOriginal['Platform'].isin(['PS2', 'X360'])], 
           fit_reg=False)
plt.xlabel('Ventas Globales', fontsize=18)
plt.ylabel('Años', fontsize=18)
plt.title('Comparación de 2 consolas de distintas épocas', fontweight='bold', fontsize=22)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-d5ef546e5a44> in <module>
# ----> 1 sns.lmplot(x='Global_Sales', y='Year', hue='Platform', figsize=(17,10),
#       2            data=vgSalesOriginal.loc[vgSalesOriginal['Platform'].isin(['PS2', 'X360'])],
#       3            fit_reg=False)
#       4 plt.xlabel('Ventas Globales', fontsize=18)
#       5 plt.ylabel('Años', fontsize=18)
#
# TypeError: lmplot() got an unexpected keyword argument 'figsize'

# %% [markdown]
# Para encontrar que tipo de género es el que más vende se generó la siguiente grafica.

# %%
VentasGlobalesGenero = vgSalesOriginal.groupby(['Genre'])['Global_Sales'].sum().sort_values(ascending=False)
sns.barplot(x=VentasGlobalesGenero.index, y=VentasGlobalesGenero.values, ec='Black', palette='PuBuGn_r')
plt.xticks(rotation=50, fontsize=12)
plt.xlabel('Género', fontsize=30)
plt.ylabel('Ventas Globales', fontsize=18)
plt.title('Ventas globales de géneros de 1980 a 2016', fontweight='bold', fontsize=22)
# Out:
# Text(0.5, 1.0, 'Ventas globales de géneros de 1980 a 2016')

# %% [markdown]
# El resultado muestra que el tipo de género "Action" es el más vendido globalmente. Con esto nos damos una idea a qué tipo de juego se puede desarrollar para tener más número de ventas en el mundo.

# %% [markdown]
# Ahora vamos a comparar las ventas de los distintos generos en todas las zonas.

# %%
top5 = vgSalesOriginal.groupby(['Genre'])['Global_Sales'].sum().sort_values(ascending=False).head(5).index

top5_genre = vgSalesOriginal[vgSalesOriginal.Genre.isin(top5)]
fig, (ax0,ax1) = plt.subplots(2,2, figsize=(17,10))

fig.suptitle('Top 5 de géneros principales y sus ventas según la región', fontsize=20, fontweight = 'bold')

sns.lineplot(x='Year', y='NA_Sales', hue='Genre', data=top5_genre, ci=None, ax=ax0[0], palette='Set1')

sns.lineplot(x='Year', y='EU_Sales', hue='Genre', data=top5_genre, ci=None, ax=ax0[1], palette='Set1')

sns.lineplot(x='Year', y='JP_Sales', hue='Genre', data=top5_genre, ci=None, ax=ax1[0], palette='Set1')

sns.lineplot(x='Year', y='Other_Sales', hue='Genre', data=top5_genre, ci=None, ax=ax1[1], palette='Set1')

ax0[0].legend(loc='upper right')
ax0[1].legend(loc='upper right')
ax1[0].legend(loc='upper right')
ax1[1].legend(loc='upper right')

ax1[1].set_ylim(-0.1,1.6)

ax0[0].set_ylabel('NA Sales', fontsize=16)
ax0[1].set_ylabel('EU Sales', fontsize=16)
ax1[0].set_ylabel('Japan Sales', fontsize=16)
ax1[1].set_ylabel('Other Sales', fontsize=16)

ax0[0].set_xlabel('Year', fontsize=16)
ax0[1].set_xlabel('Year', fontsize=16)
ax1[0].set_xlabel('Year', fontsize=16)
ax1[1].set_xlabel('Year', fontsize=16)


plt.show()

# %% [markdown]
# Para comparar este resultado con datos un poco más recientes, mostramos la siguiente grafica que nos muestra los títulos más esperados del 2018. En su mayoría el género de estos son de Acción. Con esto demostramos que la tendencia de los videojuegos del genero Acción es la indicada para desarrollar un videojuego.

# %%
from IPython.display import Image

Image('Grafica.jpeg')

# %% [markdown]
# Después de ver el resultado del género, nos dimos a la tarea de saber en que región se vende más videojuegos de este tipo.
#
# En la siguiente grafica se muestra la venta de videojuegos entre todas los desarrolladores/distribuidores en América, Europa y Japón comparada con las ventas globales

# %%
sns.jointplot(x="Global_Sales", y="NA_Sales", data=vgSalesPublisherVentasMaximas,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)

sns.jointplot(x="Global_Sales", y="EU_Sales", data=vgSalesPublisherVentasMaximas,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7,)

sns.jointplot(x="Global_Sales", y="JP_Sales", data=vgSalesPublisherVentasMaximas,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)

# %% [markdown]
# La mayoría de ventas de un juego entre el conjunto de desarrolladores/distribuidores de las ventas globales son en América, es decir que de las ventas globales de juegos de una desarrolladora, la mayor parte de sus ventas es en América

# %% [markdown]
# Después de ver la región con mayores ventas, es importante saber que consola tiene mayores ventas en videojuegos.
#
# Para mostrarlo se generó la siguiente grafica comparando todas las consolas con sus ventas totales.

# %%
f, ax = plt.subplots(figsize=(20, 15))

sns.set_color_codes("pastel")
sns.barplot(x="Global_Sales", y="Platform", data=vgSalesPlataformaSumatoriaVentas,
            label="Ventas Globales", color="b", palette='plasma')

sns.set_color_codes("muted")
sns.barplot(x="NA_Sales", y="Platform", data=vgSalesPlataformaSumatoriaVentas,
            label="Ventas en America", color="b")

plt.xlabel('Ventas en Ámerica', fontsize=18)
plt.ylabel('Consolas', fontsize=18)
plt.title('Ventas de videojuegos en diferentes consolas', fontweight='bold', fontsize=22)

sns.despine(left=True, bottom=True)

# %% [markdown]
# La ps2 y Xbox360 son las que más inversión tuvo respecto a desarrollo de juegos y la mitad de sus ventas pertenecen a la región de América y la otra mitad distribuida entre las demás regiones.
#
# Ahora, esto no quiere decir que las consolas con más inversión fueron las que tuvieron más lanzamientos de videojuegos. Para demostrarlo se hizo la siguiente gráfica.

# %%
f, ax = plt.subplots(figsize=(17,10))
consolas_lanzamientos = vgSalesOriginal['Platform'].value_counts()

sns.barplot(x=consolas_lanzamientos.values, y=consolas_lanzamientos.index, ec='Black', palette='plasma')
ax.set_title('Consolas con mas lanzamientos de videojuegos', fontweight='bold', fontsize=23)
ax.set_xlabel('Número de lanzamientos', fontsize=18)
ax.set_xlim(0, max(consolas_lanzamientos.values)+200)
ax.set_ylabel('Consola', fontsize=18)


for p in ax.patches:
    width = p.get_width()
    ax.text(width + 120,
            p.get_y() + p.get_height(),
            int(width),
            ha="center", fontsize=14)
    

plt.show()

# %% [markdown]
# La consola DS fue la que tuvo más lanzamientos de videojuegos pero no con mayores ventas. Esto quiere decir que el número de lanzamientos no afecta a las ventas.

# %% [markdown]
# Hasta en este momento sabemos que genero de videojuegos es más jugado, en donde se vende más y en que consola.
